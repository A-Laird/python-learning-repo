# %%
SELECT [EXTERNAL_ID]
      ,[GROUPED_FORM_ID]
      ,[CREATE_DTTM]
      ,[MODIF_DTTM]
      ,[DIM_ORG_ID]
      ,[DIM_LOAD_ID]
      ,[AUDIT_REFERENCE]
      ,[ARCHV_FLAG]
      ,[HDM_MODIF_DTTM]
      ,[DIM_PERSON_ID]
      ,[DIM_CONTEXT_EXTERNAL_ID]
      ,[DIM_CLIENT_ID]
      ,[DIM_CARER_ID]
      ,[FACT_REFERRAL_ID]
      ,[REVIEW_EXTERNAL_ID]
      ,[FACT_REVIEW_ID]
      ,[DIM_LOOKUP_FORM_TYPE_ID]
      ,[DIM_LOOKUP_ASSESS_TYPE_ID]
      ,[CARER_ASSESSMENT]
      ,[CLIENT_ASSESSMENT]
      ,[CLIENT_AS_CARER_ASSESSMENT]
      ,[DIM_LOOKUP_REPRT_PERIOD_ID]
      ,[DIM_ASSESSMENT_TEMPLATE_ID]
      ,[FACT_PARNT_FORM_ID]
      ,[DIM_CREATED_BY_ID]
      ,[DIM_CREATED_BY_DEPT_ID]
      ,[DIM_ASSESS_ASSIGN_USER_ID]
      ,[DIM_ASSESS_ASSIGN_DEPT_ID]
      ,[DIM_ASSESS_ASSIGN_GROUP_ID]
      ,[REQST_DTTM]
      ,[REQ_BY_DTTM]
      ,[TARGET_START_DTTM]
      ,[ACTUAL_START_DTTM]
      ,[START_DTTM]
      ,[FORM_DTTM]
      ,[TASK_COMPL_DTTM]
      ,[COMPL_DTTM]
      ,[DIM_COMPLETE_BY_ID]
      ,[DIM_COMPLETE_BY_DEPT_ID]
      ,[TARGET_END_DTTM]
      ,[END_DTTM]
      ,[DIM_LOOKUP_FORM_STATUS_ID]
      ,[DIM_AUTHORISER_ID]
      ,[DIM_AUTHORISER_DEPT_ID]
      ,[DIM_AUTH_ASSIGN_USER_ID]
      ,[DIM_AUTH_ASSIGN_GROUP_ID]
      ,[DIM_AUTH_ASSIGN_DEPT_ID]
      ,[MARKER_ID]
      ,[ASSESSMENT_INDEX]
      ,[ASSESSMENT_INDEX_KEY]
      ,[DIM_LOOKUP_ASSESS_OUTCM_1_ID]
      ,[DIM_LOOKUP_ASSESS_OUTCM_2_ID]
      ,[DIM_LOOKUP_ASSESS_OUTCM_3_ID]
      ,[DIM_LOOKUP_ASSESS_OUTCM_4_ID]
      ,[DIM_LOOKUP_ASSESS_OUTCM_5_ID]
      ,[ACTION_PLAN_NO]
      ,[REPORT_ASSESS_OUTCOME]
      ,[REP_OUTCOME_PRIORITY]
      ,[REJECTION_COMMENTS]
      ,[DIM_LOOKUP_CANC_ENDRSN_ID]
      ,[DOLS_FLAG]
      ,[SA_FLAG]
      ,[DIM_PERSON_ID_DESC]
      ,[DIM_CLIENT_ID_DESC]
      ,[DIM_CARER_ID_DESC]
      ,[DIM_LOOKUP_FORM_TYPE_ID_DESC]
      ,[DIM_LOOKUP_FORM_TYPE_ID_CODE]
      ,[DIM_LOOKUP_ASSESS_TYPE_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_TYPE_ID_CODE]
      ,[DIM_LOOKUP_REPRT_PERIOD_ID_DESC]
      ,[DIM_LOOKUP_REPRT_PERIOD_ID_CODE]
      ,[DIM_ASSESSMENT_TEMPLATE_ID_DESC]
      ,[DIM_CREATED_ID_DESC]
      ,[DIM_CREATED_DEPT_ID_DESC]
      ,[DIM_CREATED_DEPT_ID_PATH]
      ,[DIM_ASSESS_ASSIGN_USER_ID_DESC]
      ,[DIM_ASSESS_ASSIGN_DEPT_ID_DESC]
      ,[DIM_ASSESS_ASSIGN_DEPT_ID_PATH]
      ,[DIM_ASSESS_ASSIGN_GROUP_ID_DESC]
      ,[DIM_COMPLETE_BY_ID_DESC]
      ,[DIM_COMPLETE_BY_DEPT_ID_DESC]
      ,[DIM_COMPLETE_BY_DEPT_ID_PATH]
      ,[DIM_LOOKUP_FORM_STATUS_ID_DESC]
      ,[DIM_LOOKUP_FORM_STATUS_ID_CODE]
      ,[DIM_AUTHORISER_ID_DESC]
      ,[DIM_AUTHORISER_DEPT_ID_DESC]
      ,[DIM_AUTHORISER_DEPT_ID_PATH]
      ,[DIM_AUTH_ASSIGN_USER_ID_DESC]
      ,[DIM_AUTH_ASSIGN_GROUP_ID_DESC]
      ,[DIM_AUTH_ASSIGN_DEPT_ID_DESC]
      ,[DIM_AUTH_ASSIGN_DEPT_ID_PATH]
      ,[DIM_LOOKUP_ASSESS_OUTCM_1_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_OUTCM_1_ID_CODE]
      ,[DIM_LOOKUP_ASSESS_OUTCM_2_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_OUTCM_2_ID_CODE]
      ,[DIM_LOOKUP_ASSESS_OUTCM_3_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_OUTCM_3_ID_CODE]
      ,[DIM_LOOKUP_ASSESS_OUTCM_4_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_OUTCM_4_ID_CODE]
      ,[DIM_LOOKUP_ASSESS_OUTCM_5_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_OUTCM_5_ID_CODE]
      ,[DIM_LOOKUP_CANC_ENDRSN_ID_DESC]
      ,[DIM_LOOKUP_CANC_ENDRSN_ID_CODE]
      ,[ASSMNT_PRD_CMPLT_DTTM]
      ,[SP_CASE_ID]
      ,[FACT_SP_CASE_ID]
      ,[DOLS_EPISODE_ID]
      ,[FACT_DOLS_EPISODE_ID]
      ,[SA_REFERRAL_ID]
      ,[FACT_SA_REFERRAL_ID]
      ,[DIM_LOOKUP_ASSESS_INDEX_TYPE_ID]
      ,[DIM_LOOKUP_ASSESS_INDEX_TYPE_ID_DESC]
      ,[DIM_LOOKUP_ASSESS_INDEX_TYPE_ID_CODE]
      ,[APPROVED_DTTM]
      ,[FIRST_FLAG]
      ,[MOST_RECENT]
      ,[SEEN_FLAG]
      ,[CREATED_FACT_WORKER_HISTORY_ID]
      ,[CREATED_FACT_WORKER_HISTORY_TITLE]
      ,[CREATED_FACT_WORKER_HISTORY_NAME]
      ,[CREATED_FACT_WORKER_HISTORY_JOB_TITLE]
      ,[CREATED_FACT_WORKER_HISTORY_DEPARTMENT_ID]
      ,[CREATED_FACT_WORKER_HISTORY_DEPARTMENT_DESC]
      ,[CREATED_FACT_WORKER_HISTORY_DEPARTMENT_PATH]
      ,[CREATED_FACT_WORKER_HISTORY_STAFF_TYPE_CODE]
      ,[CREATED_FACT_WORKER_HISTORY_STAFF_TYPE_DESC]
      ,[ORIGINAL_FORM_ID]
      ,[REVISION_NUMBER]
      ,[LOCAL_AUTHORITY_NAME]
      ,[LOCAL_AUTHORITY_CODE]
      ,[FORM_CREATED_DATE_TIME]
      ,[ECAF_EPISODE_ID]
      ,[ECAF_CONTACT_ID]
      ,[EHCP_PATHWAY_ID]
      ,[ECAF_MULTI_ID]
      ,[LAST_MODIFIED_BY_USER_ID]
      ,[LAST_MODIFIED_BY_USER_STAFF_ID]
      ,[LAST_MODIFIED_BY_USER_NAME]
      ,[LAST_MODIFIED_BY_DEPT_ID]
      ,[LAST_MODIFIED_BY_DEPT_EXTERNAL_ID]
      ,[LAST_MODIFIED_BY_DEPT_NAME]
      ,[LAST_MODIFIED_DATE_TIME]
      ,[FACT_FORM_ID]
      ,[CREATED_HISTORY_UPDATED]
      ,[COMPLETION_NOTES]
  FROM [HDM].[Child_Social].[FACT_FORMS]
  WHERE (DIM_LOOKUP_FORM_TYPE_ID = '3674')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3675')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3676')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3677')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3679')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3680')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3681')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3682')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3683')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3684')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3685')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3686')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3687')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3688')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3690')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3691')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3692')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3693')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3694')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3695')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3696')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3697')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3698')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3699')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3701')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3702')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3703')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3704')
        OR (DIM_LOOKUP_FORM_TYPE_ID = '3705');

# %%
SELECT TOP (1000) [EXTERNAL_ID]
      ,[DESCRIPTION10]
      ,[DESCRIPTION5]
      ,[DESCRIPTION]
      ,[NAT_ID]
      ,[MAIN_CODE]
      ,[ARCHV_FLAG]
      ,[MODIF_DTTM]
      ,[CREATE_DTTM]
      ,[START_DTTM]
      ,[END_DTTM]
      ,[ORG_ID]
      ,[LOOKUP]
      ,[AUDIT_REFERENCE]
      ,[HDM_MODIF_DTTM]
      ,[DIM_ID]
      ,[DIM_LOOKUP_FORM_TYPE_ID]
  FROM [HDM].[Child_Social].[DIM_LOOKUP_FORM_TYPE]
