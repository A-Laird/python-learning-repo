# %%
#loops

#numbers = [1, 2, 3, 4, 5]

numbers = list(range(1:6))

# thing we want to loop over is the iterator?
# the element we get is the iterable?

for iterable in numbers: 
    print(iterable)

# first iterable in the list 1-6 is 1 --- we're referring to it as iterable
# so if I print it in the loop - I print 1
# second iterable in the list 1-6 is 2, so on.

# %%
names = ['Andy', 'Bob', 'Dave', 'Sam', 'Sarah']

for name in names:
    if name == 'Sarah':
        print('Done!')
    elif name == 'Andy':
        print("Hi, it's me")
    else:
#    print(f'Hello, my name is',name)
         phrase = f'Hello, my name is {name}.'
         print(phrase)
# Out:
# Hi, it's me
# Hello, my name is Bob.
# Hello, my name is Dave.
# Hello, my name is Sam.
# Done!

# %%
# enumerate adding number to list - index location and what's in the list and creating a tuple 

#dict = {'key':1}

##for tuple_i in enumerate(names_list):
##   print(tuple_i)

for index, name in enumerate(names):
    print(f"I'm {name} and I'm in index {index}.")

for key, value in dict.items():
    print(value, key)
# Out:
# I'm Andy and I'm in index 0.
# I'm Bob and I'm in index 1.
# I'm Dave and I'm in index 2.
# I'm Sam and I'm in index 3.
# I'm Sarah and I'm in index 4.

# %%
Dict_name = {'Steve':'Welder',
             'Karen':'manager',
             'Frank':'plaster',
             'Ann':'Teacher',
             'Sue':'Hit Woman'}

for k,v in Dict_name.items():
    print('My name is', k, 'and I am a', v)
# Out:
# My name is Steve and I am a Welder
# My name is Karen and I am a manager
# My name is Frank and I am a plaster
# My name is Ann and I am a Teacher
# My name is Sue and I am a Hit Woman

# %%
[13:44] William Levack-Payne (External)
dict_1 = {'key1':1,
          'key2':2}
 
names_dict = {}
 
for index, name in enumerate(names_list):
    names_dict[index] = name
 
names_dict
 
for k, v in dict_1.items():
    print(v, k)
 
# make a dictionry of 5 names and job titles
# use k,v loop to print something like "My name is NAME and I am a JOB TITLE"

# %%
[13:54] William Levack-Payne (External)
# make a dictionry of 5 names and job titles
# use k,v loop to print something like "My name is NAME and I am a JOB TITLE"
 
name_job = {'Will':'Data manager',
            'Annie':'Retired',
            'Andy':'Retired',
            'Naiomi':'Policy Writer',
            'Scout':'Moral Support'}
 
# print(name_job.keys())
# print(name_job.values())
# print(name_job.items())
 
for k, v in name_job.items():
    if (k == 'Annie') | (k == 'Andy'):
        print(f"Hi, I'm {k}, and I'm {v}.")
    else:
        print(f"Hi, I'm {k}, and I'm a {v}.")

# %%
evens = list(range(2,13,2))
odds = list(range(1,13,2))

for even in evens:
    for odd in odds:
        num = even * odd
        print(f"{even} times {odd} equals {num}")
# Out:
# 2 times 1 equals 2
# 2 times 3 equals 6
# 2 times 5 equals 10
# 2 times 7 equals 14
# 2 times 9 equals 18
# 2 times 11 equals 22
# 4 times 1 equals 4
# 4 times 3 equals 12
# 4 times 5 equals 20
# 4 times 7 equals 28
# 4 times 9 equals 36
# 4 times 11 equals 44
# 6 times 1 equals 6
# 6 times 3 equals 18
# 6 times 5 equals 30
# 6 times 7 equals 42
# 6 times 9 equals 54
# 6 times 11 equals 66
# 8 times 1 equals 8
# 8 times 3 equals 24
# 8 times 5 equals 40
# 8 times 7 equals 56
# 8 times 9 equals 72
# 8 times 11 equals 88
# 10 times 1 equals 10
# 10 times 3 equals 30
# 10 times 5 equals 50
# 10 times 7 equals 70
# 10 times 9 equals 90
# 10 times 11 equals 110
# 12 times 1 equals 12
# 12 times 3 equals 36
# 12 times 5 equals 60
# 12 times 7 equals 84
# 12 times 9 equals 108
# 12 times 11 equals 132

# %%
evens = list(range(2,13,2))
odds = list(range(1,13,2))

mulriply_list = []

for even in evens:
    for odd in odds:
        num = even * odd
        mulriply_list.append(f"{even} times {odd} equals {num}")

mulriply_list
# Out:
# ['2 times 1 equals 2',
#  '2 times 3 equals 6',
#  '2 times 5 equals 10',
#  '2 times 7 equals 14',
#  '2 times 9 equals 18',
#  '2 times 11 equals 22',
#  '4 times 1 equals 4',
#  '4 times 3 equals 12',
#  '4 times 5 equals 20',
#  '4 times 7 equals 28',
#  '4 times 9 equals 36',
#  '4 times 11 equals 44',
#  '6 times 1 equals 6',
#  '6 times 3 equals 18',
#  '6 times 5 equals 30',
#  '6 times 7 equals 42',
#  '6 times 9 equals 54',
#  '6 times 11 equals 66',
#  '8 times 1 equals 8',
#  '8 times 3 equals 24',
#  '8 times 5 equals 40',
#  '8 times 7 equals 56',
#  '8 times 9 equals 72',
#  '8 times 11 equals 88',
#  '10 times 1 equals 10',
#  '10 times 3 equals 30',
#  '10 times 5 equals 50',
#  '10 times 7 equals 70',
#  '10 times 9 equals 90',
#  '10 times 11 equals 110',
#  '12 times 1 equals 12',
#  '12 times 3 equals 36',
#  '12 times 5 equals 60',
#  '12 times 7 equals 84',
#  '12 times 9 equals 108',
#  '12 times 11 equals 132']

# %%
spreads = ['butter', 'jam', 'peanut butter']
toppings = ['ham', 'cheese', 'sardines']

combos = []

for spread in spreads:
    for topping in toppings:
        combos.append(f"{spread} plus {topping}")
combos
# Out:
# ['butter plus ham',
#  'butter plus cheese',
#  'butter plus sardines',
#  'jam plus ham',
#  'jam plus cheese',
#  'jam plus sardines',
#  'peanut butter plus ham',
#  'peanut butter plus cheese',
#  'peanut butter plus sardines']

# %%
# using these two lists of sandwich ingredients, find (using for loops) all of the spread/topping combinations
# append them to a new list of all the combos
spreads = ['butter', 'jam', 'peanut butter']
toppings = ['ham', 'cheese', 'sardines']
 
combos = []
 
for i in spreads:
    for j in toppings:
        combination = f'{i} and {j}'
        combos.append(combination)
 
print(combos)

# %%
name_job

for k in name_job.keys():
    print(name_job[k])

# %%
name_job
 
for k,v in name_job.items():
    phrase = f"Is a {v}."
    name_job[k] = phrase
 
name_job

# %%
# if - checks and does thing if true
# elif - if above ifs/elifs aren't true, tried and does thing
# else does if nothing above was true

number = 60

#if str(number) == '5':
 #   print("It's 5")

if (number % 10 == 0):
    print('Divisible by 10!')
elif (number % 3 == 0):
    print("diviible by 3")
else:
    print('not divisible by 10')
# Out:
# Yes

# %%
# my atempt 
number = []
number = list(range(1,101))

for number in number:
    if (number % 3 == 0):
        print(number, 'fizz')
        if (number % 5 == 0):
            print(number, 'Fizzbang')
    elif (number % 5 == 0):
        print(number, 'bang')
    else:
        print(number)
# Out:
# 1
# 2
# 3 fizz
# 4
# 5 bang
# 6 fizz
# 7
# 8
# 9 fizz
# 10 bang
# 11
# 12 fizz
# 13
# 14
# 15 fizz
# 15 Fizzbang
# 16
# 17
# 18 fizz
# 19
# 20 bang
# 21 fizz
# 22
# 23
# 24 fizz
# 25 bang
# 26
# 27 fizz
# 28
# 29
# 30 fizz
# 30 Fizzbang
# 31
# 32
# 33 fizz
# 34
# 35 bang
# 36 fizz
# 37
# 38
# 39 fizz
# 40 bang
# 41
# 42 fizz
# 43
# 44
# 45 fizz
# 45 Fizzbang
# 46
# 47
# 48 fizz
# 49
# 50 bang
# 51 fizz
# 52
# 53
# 54 fizz
# 55 bang
# 56
# 57 fizz
# 58
# 59
# 60 fizz
# 60 Fizzbang
# 61
# 62
# 63 fizz
# 64
# 65 bang
# 66 fizz
# 67
# 68
# 69 fizz
# 70 bang
# 71
# 72 fizz
# 73
# 74
# 75 fizz
# 75 Fizzbang
# 76
# 77
# 78 fizz
# 79
# 80 bang
# 81 fizz
# 82
# 83
# 84 fizz
# 85 bang
# 86
# 87 fizz
# 88
# 89
# 90 fizz
# 90 Fizzbang
# 91
# 92
# 93 fizz
# 94
# 95 bang
# 96 fizz
# 97
# 98
# 99 fizz
# 100 bang

# %%
# fizzbang
# take all the numbers form 1-100,
onehundred = list(range(1,101))
 
for num in onehundred:
    if (num % 3 == 0) & (num % 5 == 0):
        print('fizzbang')
    elif (num % 3 == 0):
        print('fizz')
    elif (num % 5 == 0):
        print('bang')
    else:    
        print(num)
 
# print them, BUT if the number is divisible by 3, print fizz,
# if it's divisible by 5 print bang
# BUT if it's divisible by 3 & 5 print fizzbang
# Out:
# 1
# 2
# fizz
# 4
# bang
# fizz
# 7
# 8
# fizz
# bang
# 11
# fizz
# 13
# 14
# fizzbang
# 16
# 17
# fizz
# 19
# bang
# fizz
# 22
# 23
# fizz
# bang
# 26
# fizz
# 28
# 29
# fizzbang
# 31
# 32
# fizz
# 34
# bang
# fizz
# 37
# 38
# fizz
# bang
# 41
# fizz
# 43
# 44
# fizzbang
# 46
# 47
# fizz
# 49
# bang
# fizz
# 52
# 53
# fizz
# bang
# 56
# fizz
# 58
# 59
# fizzbang
# 61
# 62
# fizz
# 64
# bang
# fizz
# 67
# 68
# fizz
# bang
# 71
# fizz
# 73
# 74
# fizzbang
# 76
# 77
# fizz
# 79
# bang
# fizz
# 82
# 83
# fizz
# bang
# 86
# fizz
# 88
# 89
# fizzbang
# 91
# 92
# fizz
# 94
# bang
# fizz
# 97
# 98
# fizz
# bang
